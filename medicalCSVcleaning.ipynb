# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\medical_disease_prediction_10000.csv")

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
df.isna().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df['Gender'], uniques = pd.factorize(df['Gender'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# df['Smoking'], uniques = pd.factorize(df['Smoking'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# df['Alcohol'], uniques = pd.factorize(df['Alcohol'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# df['PhysicalActivity'], uniques = pd.factorize(df['PhysicalActivity'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# df['FamilyHistory'], uniques = pd.factorize(df['FamilyHistory'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
# df['Disease'], uniques = pd.factorize(df['Disease'])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in ['Gender', 'Smoking', 'Alcohol', 'PhysicalActivity','FamilyHistory','Disease']:
    df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       1  17.5            102           177          161         88
# 1      69       1  31.1            118           256          147         92
# 2      61       0  31.3            114           206          193         74
# 3      47       0  23.9            105           162          253         68
# 4      47       1  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       1  27.1            177           183          268         59
# 9996   84       1  29.2            142           215          145         77
# 9997   41       1  22.8            177           265          133         71
# 9998   55       1  29.0            126           241          298         57
# 9999   59       1  32.2            151           162          225         93
#
# ...

# %%
sns.countplot(x='Disease', data=df)
plt.title('Disease Distribution')
plt.show()

# %%
sns.boxplot(x='Disease', y='Age', data=df)
plt.title('Age vs Disease')
plt.show()

# %%
sns.boxplot(x='Disease', y='BMI', data=df)
plt.title('BMI vs Disease')
plt.show()

# %%
sns.boxplot(x='Disease', y='BloodPressure', data=df)
plt.title('BloodPressure vs Disease')
plt.show()

# %%
sns.boxplot(x='Disease', y='GlucoseLevel', data=df)
plt.title('Glucose Level vs Disease')
plt.show()

# %%
sns.boxplot(x='Disease', y='Cholesterol', data=df)
plt.title('Cholesterol vs Disease')
plt.show()

# %%
pd.crosstab(df['Smoking'],df['Disease']).plot(kind='bar')
plt.title('Smoking vs Disease')
plt.show()

# %%
pd.crosstab(df['Alcohol'],df['Disease']).plot(kind='bar')
plt.title('Alcohol vs Disease')
plt.show()

# %%
pd.crosstab(df['PhysicalActivity'],df['Disease']).plot(kind='bar')
plt.title('Physical Activity vs Disease')
plt.show()

# %%
pd.crosstab(df['FamilyHistory'],df['Disease']).plot(kind='bar')
plt.title('Family History vs Disease')
plt.show()

# %%
pd.crosstab(df['Gender'],df['Disease']).plot(kind='bar')
plt.title('Gender vs Disease')
plt.show()

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       1  17.5            102           177          161         88
# 1      69       1  31.1            118           256          147         92
# 2      61       0  31.3            114           206          193         74
# 3      47       0  23.9            105           162          253         68
# 4      47       1  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       1  27.1            177           183          268         59
# 9996   84       1  29.2            142           215          145         77
# 9997   41       1  22.8            177           265          133         71
# 9998   55       1  29.0            126           241          298         57
# 9999   59       1  32.2            151           162          225         93
#
# ...

# %%
df.to_csv('cleaned_md.csv')
